# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data import RoadSatelliteModule
from system import SemanticSegmentationSystem

from models import *

import numpy as np
import matplotlib.pyplot as plt
import random

import torchvision
import torchvision.transforms.functional as F

import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping
from pytorch_lightning.callbacks import ModelCheckpoint

import torch
from torchinfo import summary

import regex as re

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %% [markdown]
# # 1. Preparation

# %%
batch_size = 8
num_workers = 8

# %%
pl.seed_everything(7, workers=True)
# Out:
# Global seed set to 7
# 7

# %% [markdown]
# ## 1.1 DataModule

# %%
road_data = RoadSatelliteModule(num_workers=num_workers, batch_size=batch_size)

# %%
# %%time
X, y = next(iter(road_data.train_dataloader()))
# Out:
# CPU times: user 36.7 ms, sys: 119 ms, total: 156 ms
# Wall time: 1.27 s

# %%
imgs, masks = next(iter(road_data.test_dataloader()))

# %% [markdown]
# ## 1.2 Inspect Data

# %%
def show_image(imgs):
    if not isinstance(imgs, list):
        imgs = [imgs]
    fix, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = img.detach()
        img = F.to_pil_image(img)
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
show_image(X[0])
show_image(y[0])

# %%
show_image(imgs[0][0])

# %% [markdown]
# # 2. Define Model / System

# %%
load_from_checkpoint = False

# %%
model = NestedUNet(1, 3)
model_name = str(model).partition('(')[0]

# %%
system = SemanticSegmentationSystem(model, road_data)

# %%
if load_from_checkpoint:
    system = SemanticSegmentationSystem.load_from_checkpoint(f'{"./lightning_logs/" + model_name + "_data"}/{model_name + "_data"}.ckpt', model=model, datamodule=road_data)

# %% [markdown]
# # 4. Training

# %%
if torch.cuda.is_available():
    gpu_count = -1
    gpu_auto_select = True
else:
    gpu_count = 0
    gpu_auto_select = False

# %%
checkpoint_callback = ModelCheckpoint(
    monitor='validation_f1',
    dirpath='./lightning_logs',
    filename=model_name + '_fix',
    save_top_k=1,
    verbose=2,
    mode='max'
)

# %%
early_stop_callback = EarlyStopping(
   monitor='validation_f1',
   patience=50,
   verbose=1,
   mode='max'
)

# %%
if load_from_checkpoint:
    trainer = pl.Trainer(
        #fast_dev_run=True,
        gpus=gpu_count,
        auto_select_gpus=gpu_auto_select,
        stochastic_weight_avg=True,
        benchmark=True,
        callbacks=[early_stop_callback, checkpoint_callback],

        resume_from_checkpoint=f'{"./lightning_logs/" + model_name + "_data"}/{model_name + "_data"}.ckpt'
    )
    
else:
        trainer = pl.Trainer(
        #fast_dev_run=True,
        gpus=gpu_count,
        auto_select_gpus=gpu_auto_select,
        stochastic_weight_avg=True,
        benchmark=True,
        callbacks=[early_stop_callback, checkpoint_callback]
    )
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores

# %%
# %%time
if not load_from_checkpoint:
    trainer.fit(system)
# Out:
#   | Name        | Type       | Params
# -------------------------------------------
# 0 | model       | NestedUNet | 2.3 M
# 1 | dice_loss   | DiceLoss   | 0
# 2 | upsample2x  | Upsample   | 0
# 3 | upsample608 | Upsample   | 0
# 4 | upsample48  | Upsample   | 0
# 5 | upsample38  | Upsample   | 0
# -------------------------------------------
# 2.3 M     Trainable params
# 0         Non-trainable params
# 2.3 M     Total params
# 9.175     Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Global seed set to 7
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Metric validation_f1 improved. New best score: 0.442
# Epoch 0, global step 10: validation_f1 reached 0.44152 (best 0.44152), saving model to "/home/cupcake/Studium/semester_10/cil/project/cil_cleanup/lightning_logs/NestedUNet_fix-v3.ckpt" as top 1
# CPU times: user 1min 5s, sys: 5.65 s, total: 1min 11s
# Wall time: 20.5 s

# %%
if gpu_count != 0:
    try:
        model.cuda()
    except:
        print("model not defined")
    try:
        model_fix.cuda()
    except:
        print("model fix not defined")
    try:
        model_fix_mask.cuda()
    except:
        print("model fix mask not defined")
else:
    try:
        model.cpu()
    except:
        print("model not defined")
    try:
        model_fix.cpu()
    except:
        print("model fix not defined")
    try:
        model_fix_mask.cpu()
    except:
        print("model fix mask not defined")
# Out:
# model fix not defined
# model fix mask not defined

# %%
system.visualize_results()

# %%
system.visualize_results_overlay()

# %% [markdown]
# # 5. Predict

# %%
if load_from_checkpoint:
    system = SemanticSegmentationSystem.load_from_checkpoint(f'{"./lightning_logs/" + model_name + "_data"}/{model_name + "_data"}.ckpt', model=model, datamodule=road_data)

# %%
if load_from_checkpoint:
    trainer.test(system, ckpt_path=f'{"./lightning_logs/" + model_name + "_data"}/{model_name + "_data"}.ckpt')

else:
    trainer.test(system)
# Out:
# Testing: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-2c19382b68e6> in <module>
#       3
#       4 else:
# ----> 5     trainer.test(system)
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py in test(self, model, test_dataloaders, ckpt_path, verbose, datamodule)
#     577
#     578         # run test
# --> 579         results = self._run(model)
#     580
#     581         assert self.state.stopped
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py in _run(self, model)
#     754
#     755         # dispatch `start_training` or `start_evaluating` or `start_predicting`
# --> 756         self.dispatch()
#     757
#     758         # plugin will finalized fitting (e.g. ddp_spawn will load trained model)
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py in dispatch(self)
#     791     def dispatch(self):
#     792         if self.evaluating:
# --> 793             self.accelerator.start_evaluating(self)
#     794         elif self.predicting:
#     795             self.accelerator.start_predicting(self)
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/accelerators/accelerator.py in start_evaluating(self, trainer)
#      97
#      98     def start_evaluating(self, trainer: 'pl.Trainer') -> None:
# ---> 99         self.training_type_plugin.start_evaluating(trainer)
#     100
#     101     def start_predicting(self, trainer: 'pl.Trainer') -> None:
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/plugins/training_type/training_type_plugin.py in start_evaluating(self, trainer)
#     146     def start_evaluating(self, trainer: 'pl.Trainer') -> None:
#     147         # double dispatch to initiate the test loop
# --> 148         self._results = trainer.run_stage()
#     149
#     150     def start_predicting(self, trainer: 'pl.Trainer') -> None:
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py in run_stage(self)
#     802
#     803         if self.evaluating:
# --> 804             return self.run_evaluate()
#     805         if self.predicting:
#     806             return self.run_predict()
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py in run_evaluate(self)
#    1042
#    1043         with self.profiler.profile(f"run_{self.state.stage}_evaluation"):
# -> 1044             eval_loop_results = self.run_evaluation()
#    1045
#    1046         # remove the tensors from the eval results
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/trainer/trainer.py in run_evaluation(self, on_epoch)
#     960                 # lightning module methods
#     961                 with self.profiler.profile("evaluation_step_and_end"):
# --> 962                     output = self.evaluation_loop.evaluation_step(batch, batch_idx, dataloader_idx)
#     963                     output = self.evaluation_loop.evaluation_step_end(output)
#     964
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/trainer/evaluation_loop.py in evaluation_step(self, batch, batch_idx, dataloader_idx)
#     168             model_ref._current_fx_name = "test_step"
#     169             with self.trainer.profiler.profile("test_step"):
# --> 170                 output = self.trainer.accelerator.test_step(args)
#     171         else:
#     172             model_ref._current_fx_name = "validation_step"
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/accelerators/accelerator.py in test_step(self, args)
#     243
#     244         with self.precision_plugin.test_step_context(), self.training_type_plugin.test_step_context():
# --> 245             return self.training_type_plugin.test_step(*args)
#     246
#     247     def predict_step(self, args: List[Union[Any, int]]) -> STEP_OUTPUT:
#
# ~/.local/lib/python3.9/site-packages/pytorch_lightning/plugins/training_type/training_type_plugin.py in test_step(self, *args, **kwargs)
#     162
#     163     def test_step(self, *args, **kwargs):
# --> 164         return self.lightning_module.test_step(*args, **kwargs)
#     165
#     166     def predict_step(self, *args, **kwargs):
#
# ~/Studium/semester_10/cil/project/cil_cleanup/system.py in test_step(self, batch, batch_idx)
#     105         X, names = batch
#     106
# --> 107         y_preds = self.predict_test_batch(X)
#     108
#     109         pred_zip = list(zip(y_preds, names))
#
# ~/Studium/semester_10/cil/project/cil_cleanup/system.py in predict_test_batch(self, X, angles)
#     115
#     116     def predict_test_batch(self, X, angles=[0, 90, 180, 270]):
# --> 117         X = X.float()
#     118         y_preds_final = []
#     119
#
# KeyboardInterrupt:

# %%
for t in system.test_results:
    show_image(t[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-496c8d16aa1a> in <module>
# ----> 1 for t in system.test_results:
#       2     show_image(t[0])
#
# TypeError: 'NoneType' object is not iterable

# %%
foreground_threshold = 0.25 # percentage of pixels > 1 required to assign a foreground label to a patch

# assign a label to a patch
def patch_to_label(patch):
    df = np.mean(patch)
    if df > foreground_threshold:
        return 1
    else:
        return 0
    
def mask_to_patched_mask(image):
    patched_image = image.squeeze().detach().clone()
    image = np.asarray(image.squeeze())
    patch_size = 16
    for j in range(0, image.shape[1], patch_size):
        for i in range(0, image.shape[0], patch_size):
            patch = image[i:i + patch_size, j:j + patch_size]
            label = patch_to_label(patch)
            patched_image[i:i + patch_size, j:j + patch_size] = label
    return patched_image

def mask_to_submission_strings(im, name):
    """Reads a single image and outputs the strings that should go into the submission file"""
    img_number = int(re.search(r"\d+", name).group(0))
    #im = mpimg.imread(image_filename) 
    # image is gray scale therefore size MxN with imread 
    patch_size = 16
    for j in range(0, im.shape[1], patch_size):
        for i in range(0, im.shape[0], patch_size):
            patch = im[i:i + patch_size, j:j + patch_size]
            label = patch_to_label(patch)
            yield("{:03d}_{}_{},{}".format(img_number, j, i, label))


def masks_to_submission(submission_filename, *images):
    """Converts images into a submission file"""
    with open(submission_filename, 'w') as f:
        f.write('id,prediction\n')
        for imgs, fn in images[0:]:
            f.writelines('{}\n'.format(s) for s in mask_to_submission_strings(imgs, fn))

# %%
batches = system.test_results

# %%
model_name

# %%
submission_filename = model_name + '_closure_predictions.csv'
pred_counter = 0

# %%
with open(submission_filename, 'w') as f:
        f.write('id,prediction\n')
        
        for mask, name in batches:
            predicted_mask = np.asarray(mask.cpu().squeeze())

            ids = mask_to_submission_strings(predicted_mask, name)
            f.writelines('{}\n'.format('\n'.join(ids)))

            pred_counter += 1
pred_counter
